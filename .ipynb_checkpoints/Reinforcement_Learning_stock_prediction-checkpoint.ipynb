# %% [markdown]
# # 0. Install and Import dependencies

# %%
# !pip install tensorflow-gpu==2.8.0 tensorflow==2.8.0 stable-baselines3 gym-anytrading gym
# Out:
# Collecting tensorflow-gpu==2.8.0
#   Downloading tensorflow_gpu-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.5 MB/s eta 0:00:00
# Collecting tensorflow==2.8.0
#   Downloading tensorflow-2.8.0-cp310-cp310-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.5 MB/s eta 0:00:00
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 19.1 MB/s eta 0:00:00
# Collecting gym-anytrading
#   Downloading gym_anytrading-2.0.0-py3-none-any.whl (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (3.9.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow-gpu==2.8.0)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow-gpu==2.8.0)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 56.0 MB/s eta 0:00:00
# Collecting tf-estimator-nightly==2.8.0.dev2021122109 (from tensorflow-gpu==2.8.0)
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 39.2 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow-gpu==2.8.0)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 53.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-gpu==2.8.0) (1.64.1)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 54.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.3.0+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow-gpu==2.8.0) (0.43.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.27.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 49.4 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 42.3 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 48.1 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-gpu==2.8.0) (3.2.2)
# Installing collected packages: tf-estimator-nightly, tensorboard-plugin-wit, keras, farama-notifications, tensorboard-data-server, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, keras-preprocessing, gymnasium, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, gym-anytrading, google-auth-oauthlib, tensorboard, tensorflow-gpu, tensorflow, stable-baselines3
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.0
#     Uninstalling google-auth-oauthlib-1.2.0:
#       Successfully uninstalled google-auth-oauthlib-1.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-gbq 0.19.2 requires google-auth-oauthlib>=0.7.0, but you have google-auth-oauthlib 0.4.6 which is incompatible.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.8.0 which is incompatible.
# Successfully installed farama-notifications-0.0.4 google-auth-oauthlib-0.4.6 gym-anytrading-2.0.0 gymnasium-0.29.1 keras-2.8.0 keras-preprocessing-1.1.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 stable-baselines3-2.3.2 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-gpu-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109

# %%
# Gym stuff
import gymnasium as gym
import gym_anytrading

# Stable baselines - rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import DQN

# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # 1. Bring in Marketwatch GME Data
# https://www.marketwatch.com/investing/stock/gme/download-data?startDate=11/1/2019&endDate=03/12/2021

# %%
df = pd.read_csv('Reliance.csv')

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close     Volume
# 0  18-11-2015  463.799988  465.649994  454.975006  456.000000  5142766.0
# 1  19-11-2015  459.450012  469.350006  458.625000  467.375000  5569752.0
# 2  20-11-2015  467.000000  476.399994  462.774994  473.424988  5167930.0
# 3  23-11-2015  475.000000  478.950012  473.100006  476.875000  4800026.0
# 4  24-11-2015  476.500000  485.799988  475.524994  483.850006  6768886.0

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# <ipython-input-5-a990aacd1078>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2015-11-18  463.799988  465.649994  454.975006  456.000000  5142766.0
# 2015-11-19  459.450012  469.350006  458.625000  467.375000  5569752.0
# 2015-11-20  467.000000  476.399994  462.774994  473.424988  5167930.0
# 2015-11-23  475.000000  478.950012  473.100006  476.875000  4800026.0
# 2015-11-24  476.500000  485.799988  475.524994  483.850006  6768886.0

# %%
env = gym.make('stocks-v0', df=df, frame_bound=(5,100), window_size=5)

# %%
env.signal_features
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.signal_features to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.signal_features` for environment variables or `env.get_wrapper_attr('signal_features')` that will search the reminding wrappers.
#   logger.warn(
# array([[ 4.5600000e+02,  0.0000000e+00],
#        [ 4.6737500e+02,  1.1375000e+01],
#        [ 4.7342499e+02,  6.0499878e+00],
#        [ 4.7687500e+02,  3.4500120e+00],
#        [ 4.8385001e+02,  6.9750061e+00],
#        [ 4.9432501e+02,  1.0475006e+01],
#        [ 4.8952499e+02, -4.8000178e+00],
#        [ 4.8354999e+02, -5.9750061e+00],
#        [ 4.8295001e+02, -5.9997600e-01],
#        [ 4.8897501e+02,  6.0249939e+00],
#        [ 4.8860001e+02, -3.7500000e-01],
#        [ 4.8272501e+02, -5.8750000e+00],
#        [ 4.7602499e+02, -6.7000122e+00],
#        [ 5.1350000e+02,  1.0299988e+01],
#        [ 5.2084998e+02,  7.3499761e+00],
#        [ 5.0587500e+02, -1.4974976e+01],
#        [ 5.0725000e+02,  1.3750000e+00],
#        [ 5.0987500e+02,  2.6250000e+00],
#        [ 5.1025000e+02,  3.7500000e-01],
#        [ 5.1087500e+02,  6.2500000e-01],
#        [ 5.0800000e+02, -2.8750000e+00],
#        [ 5.1359998e+02,  5.5999761e+00],
#        [ 5.1865002e+02,  5.0500479e+00],
#        [ 5.2392499e+02,  5.2749639e+00],
#        [ 5.1459998e+02, -9.3250122e+00],
#        [ 5.1020001e+02, -4.3999639e+00],
#        [ 5.1812500e+02,  7.9249878e+00],
#        [ 5.2352502e+02,  5.4000239e+00],
#        [ 5.2259998e+02, -9.2504799e-01],
#        [ 5.1722498e+02, -5.3750000e+00],
#        [ 5.1752502e+02,  3.0004799e-01],
#        [ 5.1347498e+02, -4.0500479e+00],
#        [ 5.1687500e+02,  3.4000239e+00],
#        [ 5.1862500e+02,  1.7500000e+00],
#        [ 5.1817499e+02, -4.5001200e-01],
#        [ 5.2015002e+02,  1.9750360e+00],
#        [ 5.2370001e+02,  3.5499880e+00],
#        [ 5.3302502e+02,  9.3250122e+00]], dtype=float32)

# %% [markdown]
# # 2. Build Environment

# %%
env.action_space
# Out:
# Discrete(2)

# %%
state = env.reset()
while True:
    action = env.action_space.sample()
    n_state, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    if done:
        print("info", info)
        break

plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': 131.8499755859375, 'total_profit': 0.9786144784493046, 'position': <Positions.Short: 0>}
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_all to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_all` for environment variables or `env.get_wrapper_attr('render_all')` that will search the reminding wrappers.
#   logger.warn(

# %%
# state = env.reset()
# while True:
#     action = env.action_space.sample()
#     result = env.step(action) # Modify to store the result in a single variable
#     # Print the result to inspect it
#     print("Result from env.step:", result)
#     if len(result) == 4:
#         n_state, reward, done, info = result  # Unpack only if there are 4 values
#         if done:
#             print("info", info)
#             break
#     else:
#         print("Unexpected number of values returned from env.step")
#         break

# plt.figure(figsize=(15,6))
# plt.cla()
# env.render_all()
# plt.show()

# %% [markdown]
# # 3. Build Environment and Train

# %%
env_maker = lambda: gym.make('stocks-v0', df=df, frame_bound=(5,100), window_size=5)
env = DummyVecEnv([env_maker])

# %%
model = DQN('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 665      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 376      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.21     |
# |    n_updates        | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 653      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 752      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43     |
# |    n_updates        | 162      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 647      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1128     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61     |
# |    n_updates        | 256      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 640      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1504     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.3      |
# |    n_updates        | 350      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 682      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1880     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.41     |
# |    n_updates        | 444      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.786    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 712      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2256     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.59     |
# |    n_updates        | 538      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 733      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.896    |
# |    n_updates        | 632      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 746      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3008     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.01     |
# |    n_updates        | 726      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 755      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3384     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.72     |
# |    n_updates        | 820      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.643    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 763      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3760     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.795    |
# |    n_updates        | 914      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.607    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 763      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4136     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.84     |
# |    n_updates        | 1008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.571    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 769      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4512     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.69     |
# |    n_updates        | 1102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 773      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4888     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.56     |
# |    n_updates        | 1196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 779      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5264     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52     |
# |    n_updates        | 1290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 781      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5640     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.304    |
# |    n_updates        | 6742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 712      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 27448    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.74     |
# |    n_updates        | 6836     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 710      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 27824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.63     |
# |    n_updates        | 6930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 705      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 28200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.941    |
# |    n_updates        | 7024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 700      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 28576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.616    |
# |    n_updates        | 7118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 694      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 28952    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.37     |
# |    n_updates        | 7212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 690      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 29328    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02     |
# |    n_updates        | 7306     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 689      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 29704    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.86     |
# |    n_updates        | 7400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 689      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 30080    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.6      |
# |    n_updates        | 7494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 689      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 30456    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.9      |
# |    n_updates        | 7588     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 689      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 30832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42     |
# |    n_updates        | 7682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 689      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 31208    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99     |
# |    n_updates        | 7776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 689      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 31584    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 7870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 689      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 31960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 7964     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 689      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 32336    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.22     |
# |    n_updates        | 8058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 689      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 32712    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 8152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 690      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 33088    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.83     |
# |    n_updates        | 8246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 690      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 33464    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.932    |
# |    n_updates        | 8340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 690      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 33840    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49     |
# |    n_updates        | 8434     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 691      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 34216    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.16     |
# |    n_updates        | 8528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 691      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 34592    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.704    |
# |    n_updates        | 8622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 692      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 34968    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0818   |
# |    n_updates        | 8716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 692      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 35344    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39     |
# |    n_updates        | 8810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 691      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 35720    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.644    |
# |    n_updates        | 8904     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 692      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 36096    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 8998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 690      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 36472    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.39     |
# |    n_updates        | 9092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 688      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 36848    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.72     |
# |    n_updates        | 9186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 686      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 37224    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 9280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 683      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 37600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.746    |
# |    n_updates        | 9374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 681      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 37976    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.38     |
# |    n_updates        | 9468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 681      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 38352    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 9562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 681      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 38728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52     |
# |    n_updates        | 9656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 681      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 39104    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0361   |
# |    n_updates        | 9750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 682      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 39480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.729    |
# |    n_updates        | 9844     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# ...
# |    n_updates        | 21594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 677      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 86856    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.481    |
# |    n_updates        | 21688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 676      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 87232    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.24     |
# |    n_updates        | 21782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 675      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 87608    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 21876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 936      |
# |    fps              | 674      |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 87984    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 21970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 672      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 88360    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.744    |
# |    n_updates        | 22064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 944      |
# |    fps              | 671      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 88736    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.524    |
# |    n_updates        | 22158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 948      |
# |    fps              | 670      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 89112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.525    |
# |    n_updates        | 22252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 952      |
# |    fps              | 668      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 89488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11     |
# |    n_updates        | 22346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 666      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 89864    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.253    |
# |    n_updates        | 22440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 663      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 90240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.38     |
# |    n_updates        | 22534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 964      |
# |    fps              | 662      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 90616    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.248    |
# |    n_updates        | 22628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 968      |
# |    fps              | 662      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 90992    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.41     |
# |    n_updates        | 22722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 972      |
# |    fps              | 661      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 91368    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.787    |
# |    n_updates        | 22816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 976      |
# |    fps              | 662      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 91744    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.51     |
# |    n_updates        | 22910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 662      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 92120    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.199    |
# |    n_updates        | 23004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 984      |
# |    fps              | 662      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 92496    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31     |
# |    n_updates        | 23098    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 988      |
# |    fps              | 662      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 92872    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.464    |
# |    n_updates        | 23192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 992      |
# |    fps              | 662      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 93248    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.94     |
# |    n_updates        | 23286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 662      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 93624    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.405    |
# |    n_updates        | 23380    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 662      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 94000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.355    |
# |    n_updates        | 23474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1004     |
# |    fps              | 662      |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 94376    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.29     |
# |    n_updates        | 23568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1008     |
# |    fps              | 662      |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 94752    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.647    |
# |    n_updates        | 23662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1012     |
# |    fps              | 662      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 95128    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.794    |
# |    n_updates        | 23756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1016     |
# |    fps              | 662      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 95504    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99     |
# |    n_updates        | 23850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 663      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 95880    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09     |
# |    n_updates        | 23944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 663      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 96256    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.62     |
# |    n_updates        | 24038    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 663      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 96632    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.601    |
# |    n_updates        | 24132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 663      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 97008    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09     |
# |    n_updates        | 24226    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 663      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 97384    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 24320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 664      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 97760    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0339   |
# |    n_updates        | 24414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 664      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 98136    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.804    |
# |    n_updates        | 24508    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 663      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 98512    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.47     |
# |    n_updates        | 24602    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 662      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 98888    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 24696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 662      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 99264    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.337    |
# |    n_updates        | 24790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 661      |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 99640    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09     |
# |    n_updates        | 24884    |
# ----------------------------------

# %% [markdown]
# # 4. Evaluation

# %%
env = gym.make('stocks-v0', df=df, frame_bound=(70,100), window_size=5)
obs, info= env.reset()
while True:
    obs = obs[np.newaxis, ...]
    action, _states = model.predict(obs)
    obs, rewards, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    if done:
        print("info", info)
        break
# Out:
# info {'total_reward': 23.949981689453125, 'total_profit': 1.063216354237601, 'position': <Positions.Long: 1>}

# %%
# env = gym.make('stocks-v0', df=df, frame_bound=(90,110), window_size=5)
# obs = env.reset()
# print(obs.shape)
# # while True:
# #     obs = obs[np.newaxis, :]
# #     action, _states = model.predict(obs)
# #     obs, rewards, done, info = env.step(action)
# #     if done:
# #         print("info", info)
# #         break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-d6b5f7c35439> in <cell line: 3>()
#       1 env = gym.make('stocks-v0', df=df, frame_bound=(90,110), window_size=5)
#       2 obs = env.reset()
# ----> 3 print(obs.shape)
#       4 # while True:
#       5 #     obs = obs[np.newaxis, :]
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
# env = gym.make('stocks-v0', df=df, frame_bound=(90,110), window_size=5)
# obs = env.reset()
# # Convert obs to a NumPy array if it's a tuple
# if isinstance(obs, tuple):
#     obs = np.array(obs)

# while True:
#     obs = obs[np.newaxis, :]
#     action, _states = model.predict(obs)
#     obs, rewards, done, info = env.step(action)
#     if done:
#         print("info", info)
#         break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-9c475fc3ba50> in <cell line: 4>()
#       3 # Convert obs to a NumPy array if it's a tuple
#       4 if isinstance(obs, tuple):
# ----> 5     obs = np.array(obs)
#       6
#       7 while True:
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py:311: UserWarning: WARN: env.render_all to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.render_all` for environment variables or `env.get_wrapper_attr('render_all')` that will search the reminding wrappers.
#   logger.warn(
